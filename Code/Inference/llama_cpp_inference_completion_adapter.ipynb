# %% [markdown]
# # Llama.cpp python inference
# https://llama-cpp-python.readthedocs.io/en/latest/

# %% [markdown]
# Inference over our trained ascii adapters

# %%
from llama_cpp import Llama

# %%
# local paths to the gguf base model and the lora adapter for generating ascii art
# get ascii art lora gguf from https://huggingface.co/pookie3000/Llama-3.2-3B-ascii-cats-lora-GGUF
# get llama 3.2 base gguf from https://huggingface.co/pookie3000/Llama-3.2-3B-GGUF
# store them locally and point to them here
# lora_path = r"E:\ASCII Cat\Llama-3.2-3B-ascii-cats-lora-q4_k_m-GGUF\Llama-3.2-3B.Q4_K_M.gguf"
# base_model_path = r"E:\ASCII Cat\Llama-3.2-3B-guide-GGUF\Llama-3.2-3B-guide-GGUF-F16.gguf"

# llm = Llama(
#     model_path=base_model_path,
#     lora_path=lora_path,
#     n_ctx=512,          # instead of 400 or higher
#     n_gpu_layers=20,    # or 10 if you have <8GB VRAM
#     verbose=False
# )



model_path = r"E:\ASCII Cat\Llama-3.2-3B-ascii-cats-lora-q4_k_m-GGUF\Llama-3.2-3B.Q4_K_M.gguf"

llm = Llama(
    model_path=model_path,
    n_ctx=1024,
    n_gpu_layers=32,
    verbose=True
)
# Out:
# ggml_cuda_init: GGML_CUDA_FORCE_MMQ:    yes
# ggml_cuda_init: GGML_CUDA_FORCE_CUBLAS: no
# ggml_cuda_init: found 1 CUDA devices:
#   Device 0: NVIDIA GeForce RTX 3060 Ti, compute capability 8.6, VMM: yes
# llama_load_model_from_file: using device CUDA0 (NVIDIA GeForce RTX 3060 Ti) - 7126 MiB free
# llama_model_loader: loaded meta data with 31 key-value pairs and 255 tensors from E:\ASCII Cat\Llama-3.2-3B-ascii-cats-lora-q4_k_m-GGUF\Llama-3.2-3B.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Unsloth_Gguf_Q0V22U92
# ...

# %%
def generate_ascii_art(max_tokens: int, generation_config) -> str:
    prompt = ""
    for chunk in llm.create_completion(
        prompt, 
        max_tokens=max_tokens, 
        stream=True, 
        temperature=generation_config["temperature"], 
        top_p=generation_config["top_p"], 
        min_p=generation_config["min_p"], 
        frequency_penalty=generation_config["frequency_penalty"], 
        presence_penalty=generation_config["presence_penalty"], 
        repeat_penalty=generation_config["repeat_penalty"], 
        top_k=generation_config["top_k"]
    ):
        chunk_text = chunk["choices"][0]["text"]
        print(chunk_text, end="", flush=True)

# %%
# nucleus sampling https://arxiv.org/pdf/1904.09751
default_generation_config = {
    # Higher values are more random. OpenAI recommmends either using temperature or top_p, but not both No effect if temperature is set to 1
    "temperature" : 0.1,
    # Model only considers the smallest set of most probable tokens whose cumulative probability exceeds top_p. No effect if top_p is set to 1
    "top_p" : 1,
    # Minimum probability required to sample a token
    "min_p" : 0,
    # Positive values penalize new tokens based on their existing frequency in the text so far
    "frequency_penalty" : 0.0,
    # Positive values penalize new tokens based on whether they appear in the text so far.
    "presence_penalty" : 0.0,
    # The penalty to apply to repeated tokens
    "repeat_penalty" : 1,
    # Only consider top_k highest probability tokens for each step
    "top_k" : 50,
}

# %%
print("Generation config: ", default_generation_config)

for i in range(10):
    print(f"Generating ascii art {i+1}\n")
    generate_ascii_art(max_tokens=200, generation_config=default_generation_config)
    print("\n\n")
# Out:
# Generation config:  {'temperature': 0.1, 'top_p': 1, 'min_p': 0, 'frequency_penalty': 0.0, 'presence_penalty': 0.0, 'repeat_penalty': 1, 'top_k': 50}
# Generating ascii art 1
#
#
#   |\__/,|   (`\
#   |o o  |__ _) )
# _.( T   )  `  /
# ((_ `^--' /_<  \
# `` `-'(((/  (((/
# llama_perf_context_print:        load time =      79.05 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /     2 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /    44 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =     775.62 ms /    46 tokens
# Generating ascii art 2
#
#
#   /\_/\  (
#  ( ^.^ ) _)
#    \"/  (
#  ( | | )
# (__d b__)
# llama_perf_context_print:        load time =      79.05 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# ...

# %%
# nucleus sampling https://arxiv.org/pdf/1904.09751
default_generation_config = {
    # Higher values are more random. OpenAI recommmends either using temperature or top_p, but not both No effect if temperature is set to 1
    "temperature" : 0.5,
    # Model only considers the smallest set of most probable tokens whose cumulative probability exceeds top_p. No effect if top_p is set to 1
    "top_p" : 1,
    # Minimum probability required to sample a token
    "min_p" : 0,
    # Positive values penalize new tokens based on their existing frequency in the text so far
    "frequency_penalty" : 0.0,
    # Positive values penalize new tokens based on whether they appear in the text so far.
    "presence_penalty" : 0.0,
    # The penalty to apply to repeated tokens
    "repeat_penalty" : 1,
    # Only consider top_k highest probability tokens for each step
    "top_k" : 50,
}

# %%
print("Generation config: ", default_generation_config)

for i in range(10):
    print(f"Generating ascii art {i+1}\n")
    generate_ascii_art(max_tokens=200, generation_config=default_generation_config)
    print("\n\n")
# Out:
# Generation config:  {'temperature': 0.5, 'top_p': 1, 'min_p': 0, 'frequency_penalty': 0.0, 'presence_penalty': 0.0, 'repeat_penalty': 1, 'top_k': 50}
# Generating ascii art 1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 5
#       3 for i in range(10):
#       4     print(f"Generating ascii art {i+1}\n")
# ----> 5     generate_ascii_art(max_tokens=200, generation_config=default_generation_config)
#       6     print("\n\n")
#
# Cell In[4], line 3, in generate_ascii_art(max_tokens, generation_config)
#       1 def generate_ascii_art(max_tokens: int, generation_config) -> str:
#       2     prompt = ""
# ----> 3     for chunk in llm.create_completion(
#       4         prompt,
#       5         max_tokens=max_tokens,
#       6         stream=True,
#       7         temperature=generation_config["temperature"],
# ...
